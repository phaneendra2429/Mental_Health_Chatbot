# %% [markdown]
# <a href="https://colab.research.google.com/github/phaneendra2429/Mental_Health_Chatbot/blob/Liz/Semantic_Search.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Sentence Similarity

# %%
# !pip install -U sentence-transformers
# Out:
# Collecting sentence-transformers
#   Downloading sentence_transformers-2.5.1-py3-none-any.whl (156 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: transformers<5.0.0,>=4.32.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.38.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.1.0+cu121)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.11.4)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.20.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (6.0.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (4.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers) (23.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.3)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (2.1.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.32.0->sentence-transformers) (0.4.2)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers) (1.3.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-2.5.1

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
import spacy
import string

#Counting KeyWords
from collections import Counter
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
#install transformers
from sentence_transformers import SentenceTransformer, util
model= SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
nlp = spacy.load("en_core_web_sm")

# %%
df_mental_health = pd.read_excel("/content/drive/MyDrive/Team 5/Depression_dataset_preprocessed (1).xlsx", sheet_name= "98_row_Mental_Health_FAQs")
df_counsellor_chats = pd.read_excel("/content/drive/MyDrive/Team 5/Depression_dataset_preprocessed (1).xlsx", sheet_name= "Counsellor_Chats")
df_human_therapist = pd.read_excel("/content/drive/MyDrive/Team 5/Depression_dataset_preprocessed (1).xlsx", sheet_name= "99_rows_Human_&_Therapist")

# %%
print(df_mental_health.columns)
print(df_counsellor_chats.columns)
print(df_human_therapist.columns)
# Out:
# Index(['Unnamed: 0', 'Question_ID', 'Questions', 'Answers',
#        'Questions_cleaned', 'Answers_cleaned'],
#       dtype='object')
# Index(['Unnamed: 0', 'questionID', 'questionTitle', 'questionText', 'topic',
#        'answerText', 'views', 'therapistInfo'],
#       dtype='object')
# Index(['Unnamed: 0', 'Human', 'Assistant'], dtype='object')

# %%
df_counsellor_chats.head()
# Out:
#    Unnamed: 0  questionID                                      questionTitle  \
# 0           0           0  Can I change my feeling of being worthless to ...
# 1           1           0  Can I change my feeling of being worthless to ...
# 2           2           0  Can I change my feeling of being worthless to ...
# 3           3           0  Can I change my feeling of being worthless to ...
# 4           4           0  Can I change my feeling of being worthless to ...
#
#                                         questionText       topic  \
# 0  I'm going through some things with my feelings...  depression
# 1  I'm going through some things with my feelings...  depression
# 2  I'm going through some things with my feelings...  depression
# 3  I'm going through some things with my feelings...  depression
# 4  I'm going through some things with my feelings...  depression
#
#                                           answerText  views  \
# 0  If everyone thinks you're worthless, then mayb...   2899
# 1  Hello, and thank you for your question and see...   3514
# 2  First thing I'd suggest is getting the sleep y...      5
# 3  Therapy is essential for those that are feelin...     31
# 4  I first want to let you know that you are not ...    620
#
#                                        therapistInfo
# 0  Sherry Katz, LCSWCouples and Family Therapist,...
# 1  Robin Landwehr, DBH, LPCC, NCCMental Health in...
# 2  Lee KingI use an integrative approach to treat...
# 3  Shauntai Davis-YearginPersonalized, private on...
# 4  Jordan WhiteLicensed Social Worker at Oak Root...

# %%
df_counsellor_chats.topic.value_counts()
# Out:
# depression                  330
# anxiety                     249
# counseling-fundamentals     240
# intimacy                    205
# relationships               174
# parenting                   145
# family-conflict             116
# self-esteem                  83
# relationship-dissolution     76
# trauma                       66
# behavioral-change            51
# marriage                     46
# lgbtq                        38
# anger-management             38
# substance-abuse              35
# spirituality                 34
# professional-ethics          32
# workplace-relationships      26
# diagnosis                    22
# domestic-violence            21
# social-relationships         20
# grief-and-loss               18
# self-harm                    11
# sleep-improvement            10
# eating-disorders             10
# legal-regulatory              8
# stress                        7
# children-adolescents          6
# addiction                     5
# human-sexuality               4
# military-issues               3
# Name: topic, dtype: int64

# %%
#Only have depression related questions
df_counsellor_chats = df_counsellor_chats[df_counsellor_chats.topic == "depression"]

# %%
# Group by the questionTitle column and aggregate the answers into a single string
combined_answers = df_counsellor_chats.groupby('questionTitle')['answerText'].agg(lambda x: ' '.join(x)).reset_index()

# %%
# Rename the columns if needed
combined_answers.columns = ['questionTitle', 'combined_answers']

# Print the resulting DataFrame
combined_answers.head()
# Out:
#                                        questionTitle  \
# 0  Can I change my feeling of being worthless to ...
# 1                     Can i learn to be happy alone?
# 2                                 Do I have anxiety?
# 3          Do I have too many issues for counseling?
# 4               Does my fiancÃ©e need a service dog?
#
#                                     combined_answers
# 0  If everyone thinks you're worthless, then mayb...
# 1  Is it possible that even though your illness i...
# 2  Everyone has some level of anxiety - it's what...
# 3  Let me start by saying there are never too man...
# 4  It sounds like you have been a positive suppor...

# %%
df1_selected= df_human_therapist[["Human", "Assistant"]]
df2_selected= df_mental_health[["Questions_cleaned", "Answers_cleaned"]]
df3_selected= combined_answers[["questionTitle", "combined_answers"]]

# %%
# Rename the columns for consistency
df2_selected.columns = ['Human', 'Assistant']
df3_selected.columns = ['Human', 'Assistant']

# %%
# Concatenate the rows of the DataFrames
combined_df = pd.concat([df1_selected, df2_selected, df3_selected], ignore_index=True)

# %%
combined_df.shape #327 rows of data
# Out:
# (327, 2)

# %%
# Count occurrences of each data type in the "Human" column
assistant_dtype_counts = combined_df['Human'].apply(type).value_counts()

# Print the counts
print("Counts of data types in 'Assistant' column:")
print(assistant_dtype_counts)
# Out:
# Counts of data types in 'Assistant' column:
# <class 'str'>      326
# <class 'float'>      1
# Name: Human, dtype: int64

# %%
# Filter rows where the input in the "Human" column is not a float
combined_df = combined_df[~combined_df['Human'].apply(lambda x: isinstance(x, float))]

# %%
#Text preprocess with string. Remove punctuations and make lowercase
def column_preprocess(df, columnname):

  def word_preprocess(text):
    text_without_punct = text.translate(str.maketrans(" ", " ", string.punctuation))
    cleaned_text = text_without_punct.lower()
    return cleaned_text
  df[columnname]= df[columnname].apply(word_preprocess)

  return df

# %%
cleaned_df = column_preprocess(combined_df, "Human")
cleaned_df = column_preprocess(combined_df, "Assistant")
# Out:
# <ipython-input-73-01198b4f45ff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[columnname]= df[columnname].apply(word_preprocess)

# %%
cleaned_df.reset_index(inplace=True)

# %%
sentences = cleaned_df["Human"]
#Encode all sentences
embeddings= model.encode(sentences)
#Compute cosine similarity between all pairs
cos_sim= util.cos_sim(embeddings, embeddings)

# %%
similarity_threshold= 0.6

#Add all pairs to a list
grouped_sentences= []

#question-group mapping

questions_to_be_grouped= {}

#counter number for grouping in numbers

group_number =1

#empty list for current group
current_group= []


for i in range(len(cos_sim)):

  #check if the index has already been grouped
  if i not in questions_to_be_grouped:
    current_group = [i]
    for j in range(len(cos_sim)):
      if i!=j and cos_sim[i][j]>=similarity_threshold:
        current_group.append(j)
        questions_to_be_grouped[j]= group_number

    group_number +=1
    if len(current_group) >1:
      grouped_sentences.append(current_group)

# %%
#Print the grouped questions with group numbers
for group_number, group in enumerate(grouped_sentences, start=1):
  print(f"Group {group_number}")
  for i in group:
    print(cleaned_df.loc[i, "Human"])
  print('\n')
# Out:
# Group 1
#  what are symptoms of panic attack vs anxiety attack
#  what’s the difference between anxiety and stress
# whats the difference between anxiety and stress
#
#
# Group 2
#  what are the types of mental illness
#  how can you treat mental illness
#  what causes mental health problems
#  what are some of the warning signs of mental illness
#  what psychological factors contribute to mental illness
#  how does someone acquire a mental illness
#  where can i learn about types of mental health treatment
#  what types of mental illness and mental health problems can be treated by a psychiatrist
# what does it mean to have a mental illness
# what causes mental illness
# what are some of the warning signs of mental illness
# where can i learn about types of mental health treatment
# what are the different types of mental health professionals
# what is mental health
# what causes mental health problems
#
#
# Group 3
#  how to manage stress
# how can i manage my anxiety
#
#
# Group 4
#  my family has no history of mental illness does that mean i am immune
#  is mental health genetic
#  are mental health problems common
#
#
# Group 5
#  are there cures for mental health problems
#  how can you treat mental illness
#  can you prevent mental health problems
#  is psychotherapy a substitute for medication
#  once someone has had a mental illness can they ever get better again
#  can people get over mental illness without medication
#  can people stabilize a mental illness simply with medication alone
#  does exercising help control mental illness just by itself
#  is mental illness a chronic disorder
#  is it possible to prevent a mental health condition
#  what types of mental illness and mental health problems can be treated by a psychiatrist
#  can people with mental illness recover
# can people with mental illness recover
# can you prevent mental health problems
# are there cures for mental health problems
#
#
# Group 6
#  what do i do if i’m worried about my mental health
#  what should i do if i’m worried about a friend or relative
#  who should i talk to about mental health
# what do i do if im worried about my mental health
# how can i see a psychiatrist
# how can i see a psychologist
# how can i see a counsellor
# how can i deal with my depression
# how can i manage my anxiety and depression so i can feel normal again
# how can i manage my anxiety
# how do i deal with depression
# how do i find out the cause of my depression and anxiety
# how do i talk about my feelings of depression and to who do i talk to
# how do i tell my parents that i think i have some mental problems
# i think i have anxiety and depression it has manifested an extreme distrust for others
# im scared to go to a doctor or take antidepressants
# is there anything i can do about my depression and anxiety
# what can i do about my depression and anxiety after trying so many things
#
#
# Group 7
#  how do i know if i’m unwell
# how do i know if im unwell
# how do i know if i have depression
# why do i feel worthless and tired
#
#
# Group 8
#  how do i deal with someone telling me what to do
# how do i deal with someone telling me what to do
#
#
# Group 9
#  what is substance abuse
# when is substance use a problem where can i go for help
# whats the difference between substance use and addiction
#
#
# Group 10
#  how much alcohol is considered “too much”
# how do i know if im drinking too much
#
#
# Group 11
#  is it normal for an older person living alone to be depressed
#  is depression different in older adults
#
#
# Group 12
#  what should i do if i know someone who appears to have all of the symptoms of a serious mental disorder
#  can i do anything for a person with a mental health issue
#  someone i really care about has mental illness but repeatedly stops taking his medication and his symptoms come back sometimes my friend has to be hospitalized how can i help him
# what should i do if i know someone who appears to have the symptoms of a mental disorder
# someone i love has been diagnosed with schizophrenia how can i help
#
#
# Group 13
#  how common are mental illnesses
#  how does someone acquire a mental illness
#  is mental illness a chronic disorder
#  is it true that nearly 90 of people who attempt or commit suicide have had some form of mental illness
#  are mental health problems common
# who does mental illness affect
# what causes mental illness
#
#
# Group 14
#  what environmental factors contribute to mental illness
#  what causes mental health problems
#  what psychological factors contribute to mental illness
#  is mental health genetic
#  how does mental health affect physical health
#  mention some facts about mental health
# who does mental illness affect
# what causes mental illness
# what causes mental health problems
#
#
# Group 15
#  why does someone with mental illness need to have a routine
#  is mental illness a chronic disorder
#
#
# Group 16
#  why do some people choose to just take meds and no therapy is that safe
#  is psychotherapy a substitute for medication
#
#
# Group 17
#  are there any ethnicracial groups that more likely to have mental illnesses
#  is mental health genetic
#
#
# Group 18
#  how many people a year commit suicide is it more than homicide
#  is it true that more people in the world have died by suicide than by homicide
#
#
# Group 19
#  where are the best resources for suicide prevention
#  how do i stop suicidal thoughts
# where can i find selfhelp materials for depression
#
#
# Group 20
#  why is it so hard to get medical coverage for mental health issues
#  why do psychiatric medications cost so much
# how can i pay for mental health care
#
#
# Group 21
#  where can i go to find a support group
# where else can i get help
# where can i go to find therapy
# where can i go to find a support group
# how can i find a support group
# im having a hard time coping with a physical health problem where can i find help
# how can i find help for an alcohol or drug use problem
#
#
# Group 22
#  can mental health cause seizures
#  what causes mental health problems
# what causes mental health problems
#
#
# Group 23
#  how can mental health issues lead to addiction
#  what causes mental health problems
#  how does someone acquire a mental illness
# what causes mental illness
# what causes mental health problems
#
#
# Group 24
#  what is the difference between a psychiatrist a psychologist and a therapist
#  what types of mental illness and mental health problems can be treated by a psychiatrist
# what is the difference between mental health professionals
# what are the different types of mental health professionals
# whats the difference between a psychiatrist and a registered psychologist
# whats the difference between psychotherapy and counselling
#
#
# Group 25
#  what’s the difference between psychotherapy and counselling
# whats the difference between psychotherapy and counselling
#
#
# Group 26
#  what types of antidepressants can psychiatrists prescribe
#  what types of mental illness and mental health problems can be treated by a psychiatrist
# whats the difference between antidepressants
#
#
# Group 27
#  can therapists prescribe medication
#  is psychotherapy a substitute for medication
#
#
# Group 28
#  what’s the difference between psychosis and neurosis
#  how is psychotic depression different than other mental disorders
# whats the difference between dissociative identity disorder multiple personality disorder and schizophrenia
# whats the difference between psychosis and schizophrenia
#
#
# Group 29
#  what’s the difference between sadness and depression
# whats the difference between sadness and depression
#
#
# Group 30
#  how do you know if you have an addiction
# how do i know if im drinking too much
#
#
# Group 31
#  how can i get help paying for my medication
# how can i get help paying for my medication
# can i get help paying for prescription medications
# how can i pay for mental health care
#
#
# Group 32
#  if i feel better after taking medication does this mean i am cured and can stop taking it
#  i have been taking my antidepressant medication for a while now i feel great all of my symptoms seem to be gone is it okay for me to stop taking my medication
# if i feel better after taking medication does this mean i am cured and can stop taking it
# should i go back on my medicine
#
#
# Group 33
#  what should i know before starting a new medication
#  will i become addicted to the medication
# what should i know before starting a new medication
#
#
# Group 34
#  if i become involved in treatment what do i need to know
# if i become involved in treatment what do i need to know
# if i become involved in treatment what do i need to know
#
#
# Group 35
#  how can i find a mental health professional right for my child or myself
#  who should i talk to about mental health
# how can i find a mental health professional for myself or my child
# how can i find a mental health professional right for my child or myself
# where can i go to find therapy
# where can i go to find inpatient care
# how can i find a doctor psychiatrist psychologist or counsellor
# how can i see a psychiatrist
# how can i see a psychologist
# how can i see a counsellor
# where can i find child and youth mental health services
# where can i find free or lowcost counselling
# im worried about my child or teenager where can i find help
# how can i get counseling if my primary care physician wont help
#
#
# Group 36
#  i heard that medication can cause sexual side effects are these effects permanent should i stop taking my medicine
#  will i become addicted to the medication
#  i was told by my doctor that i need to take the medication for the rest of my life is it absolutely true that i will have to take the medication for the rest of my life
#
#
# Group 37
#  i was recently prescribed an antidepressant the information sheet from the pharmacy said the medication may increase suicidal thoughts is this true
#  i have heard that there may be negative effects associated with stopping antidepressants is this true
#
#
# Group 38
#  what is major depressive disorder mdd
# what is dysthymia or persistent depressive disorder
#
#
# Group 39
#  what is racial trauma
#  how to deal with racism and racial trauma
#
#
# Group 40
#  what are the symptoms of psychotic depression
#  what are some of the warning signs of mental illness
#  how is psychotic depression different than other mental disorders
# what are some of the warning signs of mental illness
#
#
# Group 41
#  what causes depression
#  what causes mental health problems
# what causes mental illness
# what causes mental health problems
# why do i crave depression
#
#
# Group 42
#  how is depression diagnosed
#  how is depression treated
# where can i find more information about depression
# how do i know if i have depression
#
#
# Group 43
# what should i do if im worried about a friend or relative
#  what should i do if i’m worried about a friend or relative
#
#
# Group 44
# how can i maintain social connections what if i feel lonely
# how do i make new friends
# what can i do when i canâ€™t stand being alone
#
#
# Group 45
# how can i use distraction to manage difficult thoughts or feelings
# how do i cope with bad thoughts
#
#
# Group 46
# how can i manage grief
# how can i get over my depression and grief
#
#
# Group 47
# where can older adults find help for mental health concerns
#  who should i talk to about mental health
# where can i find child and youth mental health services
#
#
# Group 48
# where can i find selfhelp materials for anxiety
# where can i find selfhelp materials for depression
# how can i manage my anxiety
#
#
# Group 49
# i was prescribed an antidepressant or other psychiatric medication but i dont think its working what can i do
# what do i do if im worried about my mental health
# how can i deal with my depression
# how can i manage my anxiety and depression so i can feel normal again
# how do i deal with depression
# how do i get rid of depression
# how do i overcome my depression
# im scared to go to a doctor or take antidepressants
# is there anything i can do about my depression and anxiety
# what can i do about my depression and anxiety after trying so many things
#
#
# Group 50
# an adult in my life seems ill and wont find help what can i do
# im worried about my child or teenager where can i find help
# im a young person and one of my parents has a mental illness what can i do
#
#
# Group 51
# someone i love has been diagnosed with depression how can i help
#  can i do anything for a person with a mental health issue
#  someone i really care about has mental illness but repeatedly stops taking his medication and his symptoms come back sometimes my friend has to be hospitalized how can i help him
# someone i love has been diagnosed with schizophrenia how can i help
#
#
# Group 52
# i have thoughts of suicide or someone i care about is talking about suicide what should i do
#  how do i stop suicidal thoughts
# what do i do if im worried about my mental health
#
#
# Group 53
# whats the difference between mental health and mental illness
# what does it mean to have a mental illness
# what is the difference between mental health professionals
# what is mental health
# whats the difference between psychosis and schizophrenia
#
#
# Group 54
# whats the difference between anxiety and an anxiety disorder
#  what’s the difference between anxiety and stress
# whats the difference between anxiety and stress
#
#
# Group 55
# what is antisocial personality disorder
# what is obsessivecompulsive personality disorder
#
#
# Group 56
# can i change my feeling of being worthless to everyone
# i feel like my existence is meaningless
# i feel like my life is pointless
# why do i feel like i dont belong anywhere
#
#
# Group 57
# can i learn to be happy alone
# how can someone like me be happy
# what can i do when i canâ€™t stand being alone
#
#
# Group 58
# do i have anxiety
# is there anything i can do about my depression and anxiety
#
#
# Group 59
# do i have too many issues for counseling
# how can i see a counsellor
# how can i get counseling if my primary care physician wont help
#
#
# Group 60
# does my friend have depression
# i think my friend might have depression
#
#
# Group 61
# how can i be happy again
# how can someone like me be happy
# how do i get back to my fun happy self again
# how do i make myself happy without someone who made me happy
#
#
# Group 62
# how can i bring up my possible depression to my parents
# how do i talk about my feelings of depression and to who do i talk to
# how do i tell my parents that i think i have some mental problems
# how do i tell my parents that im depressed and need help
# my family says i have depression
#
#
# Group 63
# how can i control my anxiety
# how can i manage my anxiety and depression so i can feel normal again
# how can i manage my anxiety
# is there anything i can do about my depression and anxiety
#
#
# Group 64
# how can i cope with depression
#  how is depression treated
# how can i deal with depression stemming from chronic pain
# how can i deal with my depression
# how can i get over my depression and grief
# how can i manage my anxiety and depression so i can feel normal again
# how can i take care of my depression from a breakup
# how do i deal with depression
# how do i get over anxiety depression and isolation
# how do i get rid of depression
# how do i overcome my anxierty and depression
# how do i overcome my depression
# how do i talk about my feelings of depression and to who do i talk to
# i need help coping with depression as a result of stress
# is there anything i can do about my depression and anxiety
#
#
# Group 65
# how can i deal with my posttraumatic stress disorder
# how can i get over my posttraumatic stress disorder without my parents knowing about it
# how can i manage my anxiety and depression so i can feel normal again
# how do i move past my depression from being separated from the military
# i need help coping with depression as a result of stress
#
#
# Group 66
# how can i feel so empty even though im only in my early teens
# how can i stop feeling empty
# how do i stop feeling empty
# why do i feel like im nothing more than a wife and mom
# why do i feel so lonely when i have friends and attention
# why do i feel worthless and tired
# why have i been feeling empty lately
#
#
# Group 67
# how can i find myself again
# how can i get back to being the person i truly am
# how do i get to know myself
# i completely lost myselfâ€”how can i find myself again
#
#
# Group 68
# how can i love myself
# how can i stop thinking so negatively about myself
# how do i get to know myself
#
#
# Group 69
# how can you get back to my old self
# how can i get back to being the person i truly am
#
#
# Group 70
# how do i fight inner loneliness from depression and a severe anxiety disorder
# how can i manage my anxiety and depression so i can feel normal again
# how do i get over anxiety depression and isolation
# i think i have anxiety and depression it has manifested an extreme distrust for others
# what can i do about my depression and anxiety after trying so many things
#
#
# Group 71
# how would i know if i was depressed
# how do i know if im unwell
# how do i find out the cause of my depression and anxiety
# how do i know if i have depression
# how do i talk about my feelings of depression and to who do i talk to
# i always feel depressed
# i feel really down all the time
# is it possible that i have depression
# is this depression
# might i have depression
# why do i feel sad all the time
#
#
# Group 72
# i have long spurts of depression anxiety and need change constantlyâ€”why
# how can i manage my anxiety and depression so i can feel normal again
# how do i find out the cause of my depression and anxiety
# what can i do about my depression and anxiety after trying so many things
#
#
# Group 73
# im a mess physically mentally emotionally and spiritually
# im overwhelmed and depressed
#
#
# Group 74
# im depressed and unable to connect with people after my breakup
# how can i take care of my depression from a breakup
#
#
# Group 75
# im depressed because my mother kicked me out after having a child
# im depressed because my wife is divorcing me and i havent seen my child in a while
#
#
# Group 76
# im going through depression right now and my relationship is suffering
# how can i take care of my depression from a breakup
#
#
# Group 77
# im studying abroad and im depressed
# im very depressed
#
#
# Group 78
# ive been feeling sadness
# i always feel depressed
# i feel really down all the time
# im very depressed
# why do i feel sad all the time
#
#
# Group 79
# is my moodiness just a phase or do i need help
# is it possible that i have depression
# might i have depression
#
#
# Group 80
# my parents are getting a divorce and i feel depressed
# im depressed because my wife is divorcing me and i havent seen my child in a while
#
#
# Group 81
# what should i do when my parents wont let me see a therapist
# where can i go to find therapy
# how can i see a psychologist
# im a young person and one of my parents has a mental illness what can i do
# how do i tell my parents that i think i have some mental problems
# how do i tell my parents that im depressed and need help
#
#
# Group 82
# why am i so sad
# why do i feel sad all the time
#
#
# Group 83
# why am i upset or down every day even when nothing is going on
# i always feel depressed
# i feel really down all the time
# why do i feel sad all the time
